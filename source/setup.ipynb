# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
import sys
import os
sys.path.append(os.path.abspath('../utils/'))

# %%
from dwh_utils import *

# %%
dbutils.widgets.text("catalog", "acme_ecommerce", "Catalog")

catalog = dbutils.widgets.get("catalog")

source_schema = "source"
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"
volume_name = "data-sources"

# %% [markdown]
# ## Catalog

# %%
catalog_created = create_catalog(spark=spark, catalog=catalog)
print(catalog_created)

if not catalog_created:
  raise Exception(f"Issue encountered while creating the catalog: {catalog}")

# %% [markdown]
# ## Schema

# %%
source_schema_created = create_schema(spark=spark, catalog=catalog, schema=source_schema)

if not source_schema_created:
  raise Exception(f"Issue encountered while creating the schema: {source_schema}")

# %%
bronze_schema_created = create_schema(spark=spark, catalog=catalog, schema=bronze_schema)

if not bronze_schema_created:
  raise Exception(f"Issue encountered while creating the schema: {bronze_schema}")

# %%
silver_schema_created = create_schema(spark=spark, catalog=catalog, schema=silver_schema)

if not silver_schema_created:
  raise Exception(f"Issue encountered while creating the schema: {silver_schema}")

# %%
gold_schema_created = create_schema(spark=spark, catalog=catalog, schema=gold_schema)

if not gold_schema_created:
  raise Exception(f"Issue encountered while creating the schema: {gold_schema}")

# %% [markdown]
# ## Volume

# %%
volume_created = create_volume(spark=spark, catalog=catalog, schema=bronze_schema, volume=volume_name)
if not volume_created:
  raise Exception(f"Issue encountered while creating the view: {volume_name}")

# %%
dbutils.fs.mkdirs(create_directory_path(spark=spark, catalog=catalog, schema=source_schema, volume=volume_name, directory="customers"))
dbutils.fs.mkdirs(create_directory_path(spark=spark, catalog=catalog, schema=source_schema, volume=volume_name, directory="orders"))
dbutils.fs.mkdirs(create_directory_path(spark=spark, catalog=catalog, schema=source_schema, volume=volume_name, directory="products"))
