# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
import sys
import os
sys.path.append(os.path.abspath('../utils/'))

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StructType
import json
from dwh_utils import *
from transformation_utils import *

# %%
df = spark.read.option("header", True).csv("/Volumes/acme_ecommerce/source/data-sources/products/*.csv").withColumn("ingest_timestamp", F.current_timestamp()).select("*", "_metadata.file_path")

# %%
df = normalize_column_names(spark=spark, df=df)

# %%
df.columns

# %%
write_to_delta_with_cdc_by_name(
    spark=spark, df=df, catalog="acme_ecommerce", schema="bronze", table="products", merge_keys=["product_id", "product_name"], append_only=True
)
